# %% [markdown]
# <a href="https://colab.research.google.com/github/nadhimmna/Tugas-Machine-Learning/blob/main/Tugas%20Minggu%205/Tugas5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Muhammad Nadhim Abdirrahman
# NIM : 1103210018
# Kelas : TK4505
# Dataset : IT Salary Survey EU 2020.csv

# %%
# library yang diperlukan
import pandas as pd

# Mounting google colab dengan google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Baca dataset IT Salary Survey EU 2020.csv
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/IT Salary Survey EU  2020.csv')
# Menampilkan lima baris pertama dari data
df.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
# Promt : berikan kode untuk menampilkan feature statistic
# feature statistic
print("statistik")
df.describe()
# Out:
# statistik
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %%
# Promt : buat kode untuk menampilkan data pada dataset IT Salary Survey EU 2020.csv
# Menampilkan informasi singkat tentang dataset
print("\nInformasi tentang dataset:")
df.info()
# Out:
# Informasi tentang dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
# Promt : beri kode untuk memperbarui nama nama fitur
# Memperbarui nama kolom
df.columns = [
    'Timestamp',
    'Age',
    'Gender',
    'City',
    'Position',
    'Total_Experience',
    'Experience_in_Germany',
    'Seniority_Level',
    'Main_Technology',
    'Other_Technologies',
    'Yearly_Salary',
    'Yearly_Bonus_Stocks',
    'Previous_Year_Salary',
    'Previous_Year_Bonus_Stocks',
    'Vacation_Days',
    'Employment_Status',
    'Contract_Duration',
    'Main_Language',
    'Company_Size',
    'Company_Type',
    'Job_Loss_Due_to_Covid',
    'Reduced_Working_Hours',
    'Additional_Monetary_Support'
]

# Menampilkan data setelah pembaruan nama kolom
print("\nLima baris pertama dari data setelah pembaruan nama kolom:")
df.head()
# Out:
# Lima baris pertama dari data setelah pembaruan nama kolom:
#              Timestamp   Age Gender    City            Position  \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total_Experience Experience_in_Germany Seniority_Level  \
# 0                5                     3          Senior
# 1                7                     4          Senior
# 2               12                     6            Lead
# 3                4                     1          Junior
# 4               17                     6          Senior
#
#            Main_Technology               Other_Technologies  ...  \
# 0               TypeScript  Kotlin, Javascript / Typescript  ...
# ...

# %%
# Promt : beri kode untuk memperbarui nama nama fitur
# Menangani nilai yang hilang
print("\nJumlah nilai yang hilang untuk setiap kolom:")
print(df.isnull().sum())
# Out:
# Jumlah nilai yang hilang untuk setiap kolom:
# Timestamp                        0
# Age                             27
# Gender                          10
# City                             0
# Position                         6
# Total_Experience                16
# Experience_in_Germany           32
# Seniority_Level                 12
# Main_Technology                127
# Other_Technologies             157
# Yearly_Salary                    0
# Yearly_Bonus_Stocks            424
# Previous_Year_Salary           368
# Previous_Year_Bonus_Stocks     639
# Vacation_Days                   68
# Employment_Status               17
# Contract_Duration               29
# Main_Language                   16
# Company_Size                    18
# Company_Type                    25
# Job_Loss_Due_to_Covid           20
# Reduced_Working_Hours          880
# Additional_Monetary_Support    791
# dtype: int64

# %%
# Promt : beri kode untuk membersihkan dataset
# Membersihkan data
print("Status:")
# Menghapus baris yang memiliki nilai null
df.dropna(inplace=True)
# Menghapus duplikat baris
df.drop_duplicates(inplace=True)
# Mengonversi tipe data yang salah
df['Age'] = df['Age'].astype(int)
# Mengonversi format kolom 'Timestamp' menjadi datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
# Mengonversi kolom 'Yearly_Bonus_Stocks' dan 'Previous_Year_Bonus_Stocks' ke tipe data numerik
df['Yearly_Bonus_Stocks'] = pd.to_numeric(df['Yearly_Bonus_Stocks'], errors='coerce')
df['Previous_Year_Bonus_Stocks'] = pd.to_numeric(df['Previous_Year_Bonus_Stocks'], errors='coerce')
print("Data berhasil dibersihkan.")
# Out:
# Status:
# Data berhasil dibersihkan.

# %%
# Promt : beri kode untuk memvisualisasikan dataset
# library yang diperlukan
import matplotlib.pyplot as plt
import seaborn as sns

# Membaca file CSV
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/IT Salary Survey EU  2020.csv')

# Pilih hanya kolom-kolom numerik untuk heatmap korelasi
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Buat subset dari dataframe yang hanya berisi kolom numerik
df_numeric = df[numeric_cols]

# Visualisasi Histogram untuk kolom 'Age'
plt.figure(figsize=(8, 4))
sns.histplot(data=df, x='Age', bins=20, kde=True, color='skyblue')
plt.title('Distribusi Usia')
plt.xlabel('Usia')
plt.ylabel('Frekuensi')
plt.grid(True)
plt.tight_layout()
plt.show()

# Visualisasi Heatmap untuk korelasi antara kolom numerik
plt.figure(figsize=(6, 4))
heatmap = sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
heatmap.set_title('Heatmap Korelasi antar Fitur', pad=20)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-9aed78ec0581>:29: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
